# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pivot Tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    780     20   John  January      Q1
# 1  2023-01-02       B   West    771     88   Mary  January      Q1
# 2  2023-01-03       C  North    476     95    Bob  January      Q1
# 3  2023-01-04       D  South    511     54  Alice  January      Q1
# 4  2023-01-05       A   East    566     78   John  January      Q1
# 5  2023-01-06       B   West    875     95   Mary  January      Q1
# 6  2023-01-07       C  North    365     84    Bob  January      Q1
# 7  2023-01-08       D  South    720     30  Alice  January      Q1
# 8  2023-01-09       A   East    497     80   John  January      Q1
# 9  2023-01-10       B   West    269     59   Mary  January      Q1
# 10 2023-01-11       C  North    641     82    Bob  January      Q1
# 11 2023-01-12       D  South    306     66  Alice  January      Q1
# 12 2023-01-13       A   East    586     67   John  January      Q1
# 13 2023-01-14       B   West    284     35   Mary  January      Q1
# 14 2023-01-15       C  North    281     74    Bob  January      Q1
# 15 2023-01-16       D  South    967     95  Alice  January      Q1
# 16 2023-01-17       A   East    725     41   John  January      Q1
# 17 2023-01-18       B   West    595     66   Mary  January      Q1
# 18 2023-01-19       C  North    492     22    Bob  January      Q1
# 19 2023-01-20       D  South    121     68  Alice  January      Q1

# %%
pd.pivot_table(df,values ="Sales",index='Region',columns="Product",aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     586.0    NaN    NaN    NaN
# North      NaN    NaN  476.0    NaN
# South      NaN    NaN    NaN  511.0
# West       NaN  595.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     630.8    NaN    NaN    NaN  57.2   NaN   NaN   NaN
# North      NaN    NaN  451.0    NaN   NaN   NaN  71.4   NaN
# South      NaN    NaN    NaN  525.0   NaN   NaN   NaN  62.6
# West       NaN  558.8    NaN    NaN   NaN  68.6   NaN   NaN

# %% [markdown]
# **Cross Table**

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
